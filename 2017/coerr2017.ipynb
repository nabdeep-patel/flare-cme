# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
positive = pd.read_csv("positive_2017.csv")
positive["CME"] = 1
negative = pd.read_csv("negative_2017.csv")
negative["CME"] = 0

data = pd.concat([positive,negative],axis=0, ignore_index=True)
data
# Out:
#      Unnamed: 0        USFLUX  MEANGBT   MEANJZH    MEANPOT  SHRGT45  \
# 0             0  2.246101e+22  107.736  0.021724  15533.100   54.882
# 1             1  2.235615e+22   93.863 -0.001943  10914.060   44.178
# 2             2  6.039302e+22   91.233  0.007535   9912.353   29.044
# 3             3  2.384940e+22  109.706  0.009620   3703.910   13.500
# 4             4  1.989983e+22  109.891  0.032849  12062.610   44.090
# ..          ...           ...      ...       ...        ...      ...
# 414         344  3.595285e+22   84.079 -0.003574  15462.530   56.773
# 415         345  4.799015e+22   69.899 -0.003790   9372.617   37.308
# 416         346  4.290416e+21  107.452 -0.008571   3137.937    9.761
# 417         347  1.749252e+22   98.802  0.006088   7534.002   35.434
# 418         348  2.467425e+22   95.711  0.007345   6833.951   33.942
#
#       TOTUSJH  MEANGBH   MEANALP  MEANGAM  ...        TOTPOT  MEANSHR  \
# 0    2975.118   77.983  0.041413   59.541  ...  7.077275e+23   50.329
# 1    1636.710   56.639 -0.003942   50.680  ...  4.733711e+23   43.479
# 2    4229.148   49.560  0.015028   41.150  ...  1.074422e+24   35.873
# 3    1505.331   47.602  0.030907   34.321  ...  1.879337e+23   28.525
# 4    2547.054   73.681  0.079865   53.270  ...  5.269515e+23   43.929
# ..        ...      ...       ...      ...  ...           ...      ...
# 414  2778.955   55.143 -0.006698   57.445  ...  1.140017e+24   50.285
# 415  2963.899   39.526 -0.008385   46.920  ...  9.161178e+23   40.655
# 416   307.977   48.775 -0.020222   31.296  ...  2.437881e+22   25.281
# 417  1197.252   52.201  0.014262   45.836  ...  2.709086e+23   38.791
# 418  1999.820   53.686  0.017490   44.576  ...  3.421573e+23   38.488
#
#         AREA_ACR  R_VALUE   ABSNJZH  HARPNUM   NOAA  Class  \
# 0     945.314636    4.805   745.287      377  11158   X2.2
# 1     961.502686    4.303    63.441      401  11166   M2.0
# 2    1934.446167    4.865   615.008      393  11164   M3.7
# 3     970.551636    3.971   367.530      637  11226   M2.5
# 4    1259.099854    4.777  1080.528      750  11261   M6.0
# ..           ...      ...       ...      ...    ...    ...
# 414  1467.530029    4.650   198.429     6670  12567   M1.2
# 415  1376.174561    4.582   278.922     6670  12567   M5.0
# 416    69.755775    3.404    50.138     6870  12615   M1.2
# 417   571.571899    4.322   164.838     6972  12644   M2.3
# 418   798.758362    4.523   276.909     6972  12644   M5.7
#
#                 Peak Time  CME
# 0    2011.02.14_01:56_TAI    1
# 1    2011.03.06_14:30_TAI    1
# 2    2011.03.06_20:12_TAI    1
# 3    2011.06.06_06:41_TAI    1
# 4    2011.08.02_13:48_TAI    1
# ..                    ...  ...
# 414  2016.07.20_00:46_TAI    0
# 415  2016.07.22_02:11_TAI    0
# 416  2016.11.28_23:38_TAI    0
# 417  2017.04.01_13:00_TAI    0
# 418  2017.04.01_20:33_TAI    0
#
# [419 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'USFLUX', 'MEANGBT', 'MEANJZH', 'MEANPOT', 'SHRGT45',
#        'TOTUSJH', 'MEANGBH', 'MEANALP', 'MEANGAM', 'MEANGBZ', 'MEANJZD',
#        'TOTUSJZ', 'SAVNCPP', 'TOTPOT', 'MEANSHR', 'AREA_ACR', 'R_VALUE',
#        'ABSNJZH', 'HARPNUM', 'NOAA', 'Class', 'Peak Time', 'CME'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0','HARPNUM', 'NOAA', 'Class', 'Peak Time'],axis =1 )
data
# Out:
#            USFLUX  MEANGBT   MEANJZH    MEANPOT  SHRGT45   TOTUSJH  MEANGBH  \
# 0    2.246101e+22  107.736  0.021724  15533.100   54.882  2975.118   77.983
# 1    2.235615e+22   93.863 -0.001943  10914.060   44.178  1636.710   56.639
# 2    6.039302e+22   91.233  0.007535   9912.353   29.044  4229.148   49.560
# 3    2.384940e+22  109.706  0.009620   3703.910   13.500  1505.331   47.602
# 4    1.989983e+22  109.891  0.032849  12062.610   44.090  2547.054   73.681
# ..            ...      ...       ...        ...      ...       ...      ...
# 414  3.595285e+22   84.079 -0.003574  15462.530   56.773  2778.955   55.143
# 415  4.799015e+22   69.899 -0.003790   9372.617   37.308  2963.899   39.526
# 416  4.290416e+21  107.452 -0.008571   3137.937    9.761   307.977   48.775
# 417  1.749252e+22   98.802  0.006088   7534.002   35.434  1197.252   52.201
# 418  2.467425e+22   95.711  0.007345   6833.951   33.942  1999.820   53.686
#
#       MEANALP  MEANGAM  MEANGBZ   MEANJZD       TOTUSJZ       SAVNCPP  \
# 0    0.041413   59.541  117.582  0.104880  5.032922e+13  1.226148e+13
# 1   -0.003942   50.680   99.163  0.130367  3.344854e+13  3.884153e+12
# 2    0.015028   41.150  100.010 -0.131131  7.631205e+13  3.430647e+13
# 3    0.030907   34.321  110.939  0.004581  3.136324e+13  1.969386e+13
# 4    0.079865   53.270  115.866  0.322013  4.301247e+13  4.460671e+13
# ..        ...      ...      ...       ...           ...           ...
# 414 -0.006698   57.445   90.077  0.124492  5.565462e+13  3.831554e+12
# 415 -0.008385   46.920   76.611  0.062467  5.389699e+13  9.294740e+12
# 416 -0.020222   31.296  119.937 -0.014350  5.516376e+12  1.985415e+12
# 417  0.014262   45.836  103.963 -0.129744  2.529872e+13  8.062131e+12
# 418  0.017490   44.576  107.240 -0.159914  4.061303e+13  7.438095e+12
#
#            TOTPOT  MEANSHR     AREA_ACR  R_VALUE   ABSNJZH  CME
# 0    7.077275e+23   50.329   945.314636    4.805   745.287    1
# 1    4.733711e+23   43.479   961.502686    4.303    63.441    1
# 2    1.074422e+24   35.873  1934.446167    4.865   615.008    1
# 3    1.879337e+23   28.525   970.551636    3.971   367.530    1
# 4    5.269515e+23   43.929  1259.099854    4.777  1080.528    1
# ..            ...      ...          ...      ...       ...  ...
# 414  1.140017e+24   50.285  1467.530029    4.650   198.429    0
# 415  9.161178e+23   40.655  1376.174561    4.582   278.922    0
# 416  2.437881e+22   25.281    69.755775    3.404    50.138    0
# 417  2.709086e+23   38.791   571.571899    4.322   164.838    0
# 418  3.421573e+23   38.488   798.758362    4.523   276.909    0
#
# [419 rows x 19 columns]

# %%
corr_matrix = data.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, 
            annot=True,        # Show the correlation coefficients
            cmap='coolwarm',
            fmt=".2f",       # Color map ranging from blue (-1) to red (1)
            vmin=-1, vmax=1,   # Fix color scale range
            center=0,          # Center color scale at 0
            square=True,       # Keep cells square
            linewidths=0.5,    # Add lines between cells
            cbar_kws={"shrink": 0.75})  # Shrink color bar

plt.title("Correlation Matrix 2016 Heatmap")
plt.tight_layout()
plt.show()
